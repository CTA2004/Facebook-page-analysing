# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
new_df = pd.read_csv('new-final-project-CTA2004thaythuantoan.csv')

# %%
date_unique = new_df['date'].unique()
date_unique.tolist()
# Out:
# ['2023-11-20',
#  '2023-11-19',
#  '2023-11-18',
#  '2023-11-17',
#  '2023-11-16',
#  '2023-11-15',
#  '2023-11-14',
#  '2023-11-13',
#  '2023-11-12',
#  '2023-11-11',
#  '2023-11-10',
#  '2023-11-09',
#  '2023-11-08',
#  '2023-11-07',
#  '2023-11-06']

# %%
hour_unique = new_df['hour'].unique()
hour_unique.tolist()
# Out:
# [11, 10, 0, 23, 22, 21, 19, 18, 20, 12, 16, 17]

# %%
posts_in_19_11 = new_df[new_df['date'] == '2023-11-19']
posts_in_19_11
# Out:
#             post_id                                               text  \
# 4   376038214986290  [TOPIC]\nXét tuyển đại học bằng IELTS liệu có ...
# 5   376074714982640  Alisa phiên bản cô Thường ở một trường nào đó ...
# 6   376073691649409  🔥ĐỀ KSCL CUỐI HK1 LẦN 4 KÈM ĐÁP ÁN CHI TIẾT VỪ...
# 7   376052998318145  Bảng điểm KSCL CUỐI KÌ 1 LẦN 4\nCó tổng 902 bạ...
# 8   376033778320067  Một ngày bình thường ở Đại học 😇 #viralreels #...
# 9   375970418326403  [ 🎊CHÍNH THỨC MỞ LINK THI KSCL CUỐI HK1 LẦN 4]...
# 10  375958611660917  Cuộc thi " VIẾT VỀ NGƯỜI THẦY TRONG TRÁI TYM T...
# 11  375946588328786  🎉 BÀI DỰ THI CUỘC THI:"Vẻ đẹp của người thầy t...
# 12  375803445009767  19h30 tối nay vào thi KSCL CUỐI HK1 cùng thầy ...
# 13  375785811678197  🔥TUYỂN TẬP NHỮNG CÂU HAY CHƯƠNG HÌNH OXYZ\n===...
#
#                                             post_text                 time  \
# 4   [TOPIC]\nXét tuyển đại học bằng IELTS liệu có ...  2023-11-19 23:00:06
# ...

# %%
posts_in_11_hour = new_df[new_df['hour'] == 11]
posts_in_11_hour
# Out:
#             post_id                                               text  \
# 0   376364734953638  Gửi tặng các em đề thi thử KSCL cuối HK1 do đí...
# 1   376341941622584  📌Lịch học dành cho 2K6 , 2K7 và 2K8 tuần tới n...
# 12  375803445009767  19h30 tối nay vào thi KSCL CUỐI HK1 cùng thầy ...
# 13  375785811678197  🔥TUYỂN TẬP NHỮNG CÂU HAY CHƯƠNG HÌNH OXYZ\n===...
# 21  375236515066460  TÀI LIỆU LIVESTREAM KHOÁ 2K6\nChủ đề : Phương ...
# 26  374717681785010  Gửi tặng các em file đề + đáp án chi tiết phần...
# 35  374164261840352  Thầy Thuận lập nhóm F.R.E.E nhận TÀI LIỆU VIP+...
# 36  374153638508081  🔥Thầy gửi tặng các em bản chép tay Bài 10 : Bà...
# 43  373620318561413  Hello các em, thầy vừa mới lập 1 group chuyên ...
# 44  373575488565896  𝐓𝐀̀𝐈 𝐋𝐈𝐄̣̂𝐔 𝐊𝐇𝐎́𝐀 𝐇𝐎̣𝐂 𝐋𝐎̛́𝐏 𝐋𝐈𝐕𝐄 𝐕𝐈𝐏 𝟐𝐊𝟔\nBÀI...
# 50  373088701947908  🔥Thầy Thuận gửi tặng các em Full file bản đẹp ...
# 63  371990555391056  Đúng 19h30 tối nay thầy mở lin.k THI THỬ KSCL ...
# ...

# %%
new_df['date'].value_counts()
# Out:
# 2023-11-19    10
# 2023-11-16    10
# 2023-11-11     9
# 2023-11-08     9
# 2023-11-18     8
# 2023-11-15     8
# 2023-11-12     8
# 2023-11-10     8
# 2023-11-14     6
# 2023-11-17     5
# 2023-11-13     5
# 2023-11-07     5
# 2023-11-20     4
# 2023-11-09     3
# 2023-11-06     2
# Name: date, dtype: int64

# %%
new_df['date'].value_counts().plot(kind = "bar", figsize= (14, 6))
# Out:
# <Axes: >

# %%
new_df['hour'].value_counts()
# Out:
# 11    17
# 22    13
# 21    13
# 20    13
# 18    12
# 23    11
# 19     9
# 10     4
# 17     4
# 12     2
# 0      1
# 16     1
# Name: hour, dtype: int64

# %%
new_df['hour'].value_counts().plot(kind = "bar", figsize= (14, 6))
# Out:
# <Axes: >

# %%
new_df.plot(kind='scatter', x='date', y='hour', figsize = (20, 10))
# Out:
# <Axes: xlabel='date', ylabel='hour'>
